# %% [markdown]
# # 대스타
#
# 클래스 이름 --> 숫자로 바꾸기

# %%
#csv 파일 --> pandas 
import pandas as pd

#파일 경로를 위한 라이브러리
import os

# %%
#현재 작업 폴더 확인

os.getcwd()
# Out:
# 'C:\\Users\\user\\Desktop\\train'

# %%
root = 'C:/Users/user/Desktop/train/re_train'

list = os.listdir(root)

# %%
label = {}

for i in range(len(list)):
    label[i] = list[i]

# %%
label
# Out:
# {0: '가는기린초',
#  1: '가막살나무',
#  2: '가문비나무',
#  3: '가시여뀌',
#  4: '가을강아지풀',
#  5: '가침박달',
#  6: '각시취',
#  7: '감국',
#  8: '개갓냉이',
#  9: '개구리발톱',
#  10: '개구리자리',
#  11: '개기장',
#  12: '개다래',
#  13: '개똥쑥',
#  14: '개병풍',
#  15: '개쑥부쟁이',
#  16: '개양귀비',
#  17: '개여뀌',
#  18: '개옻나무',
#  19: '개찌버리사초',
#  20: '갯패랭이꽃',
#  21: '거제수나무',
#  22: '고광나무',
#  23: '고들빼기',
#  24: '고려엉겅퀴',
#  25: '고본',
#  26: '고욤나무',
#  27: '고추나무',
#  28: '고추나물',
#  29: '과남풀',
#  30: '괴불나무',
#  31: '구상나무',
#  32: '구절초',
#  33: '국수나무',
#  34: '그늘흰사초',
#  35: '그령',
#  36: '금강아지풀',
#  37: '금강초롱꽃',
#  38: '금계국',
#  39: '금꿩의다리',
#  40: '금방동사니',
#  41: '금불초',
#  42: '기린초',
#  43: '긴산꼬리풀',
#  44: '까마귀머루',
#  45: '까마귀밥나무',
#  46: '까실쑥부쟁이',
#  47: '까치고들빼기',
#  48: '깽깽이풀',
#  49: '꼬리조팝나무',
#  50: '꼬리풀',
#  51: '꽃다지',
#  52: '꽃마리',
#  53: '꽃며느리밥풀',
#  54: '꽃범의꼬리',
#  55: '꽃향유',
#  56: '꽝꽝나무',
#  57: '꿀풀',
#  58: '끈끈이여뀌',
#  59: '나도개피',
#  60: '나도냉이',
#  61: '나도바람꽃',
#  62: '나도생강',
#  63: '나래박쥐나물',
#  64: '나래새',
#  65: '낙지다리',
# ...

# %%
df = pd.DataFrame(list)

df
# Out:
#           0
# 0     가는기린초
# 1     가막살나무
# 2     가문비나무
# 3      가시여뀌
# 4    가을강아지풀
# ..      ...
# 304    환삼덩굴
# 305      황금
# 306    황새냉이
# 307    회목나무
# 308     흰여뀌
#
# [309 rows x 1 columns]

# %%
df.to_csv("C:/Users/user/Desktop/train/label.csv", encoding = 'cp949')

# %%
len(label)
# Out:
# 309

# %%
for i in range(len(list)):
    os.rename(f'{root}/{list[i]}', f'{i}')

# %%
#위의 폴더 이름을 바꿀때 바꾸는 이름에도 원하는 경로 지정 필요! 
#안할시 현재 경로에 저장된다.
